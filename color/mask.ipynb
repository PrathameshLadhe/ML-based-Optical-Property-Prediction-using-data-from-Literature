# %%
# !pip install opencv-contrib-python
# !pip install matplotlib
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab.patches import cv2_imshow as cv_imshow

# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks'
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/opencv
# Out:
# /content/gdrive/My Drive/Colab Notebooks/opencv

# %%
img = cv.imread('image')
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

# %%
(height,width) = img.shape[:2]

# %%
data = np.reshape(img,(height * width,3))
data = np.float32(data)
number_clusters = 3
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 10, 1.0)
flags = cv.KMEANS_RANDOM_CENTERS
compactness, labels, centers = cv.kmeans(data, number_clusters, None, criteria, 10, flags)
print(centers)
# Out:
# [[153.65636  150.3826   150.51971 ]
#  [251.69759  251.82542  251.71872 ]
#  [ 32.935135  49.99828   32.887875]]

# %%
lower = np.array([129, 50,70])
upper = np.array([158, 255, 255])

# %%
lower_red1 = np.array([159, 50, 70])
upper_red1 = np.array([180, 255, 255])

lower_red2 = np.array([0, 50, 70])
upper_red2 = np.array([9, 255, 255])

# %% [markdown]
# color_dict_HSV = {'black': [[180, 255, 30], [0, 0, 0]],
#               'white': [[180, 18, 255], [0, 0, 231]],
#               'red1': [[180, 255, 255], [159, 50, 70]],
#               'red2': [[9, 255, 255], [0, 50, 70]],
#               'green': [[89, 255, 255], [36, 50, 70]],
#               'blue': [[128, 255, 255], [90, 50, 70]],
#               'yellow': [[35, 255, 255], [25, 50, 70]],
#               'purple': [[158, 255, 255], [129, 50,70],
#               'orange': [[24, 255, 255], [10, 50, 70]],
#               'gray': [[180, 18, 230], [0, 0, 40]]}

# %%
hsvnot = cv.bitwise_not(hsv)

# %%
lower_black = np.array([0, 0, 0])
upper_black = np.array([180, 255, 30])
lower_blue =  np.array([90, 50, 70])
upper_blue = np.array([128, 255, 255])
lower_purple = np.array([129, 50,70])
upper_purple = np.array([158, 255, 255])
lower_white =  np.array([0, 0, 231])
upper_white = np.array([180, 18, 255])
lower_green = np.array([36, 50, 70])
upper_green = np.array([89, 255, 255])
lower_grey =  np.array([0, 0, 40])
upper_grey = np.array([180, 20, 100])

# %%
mask_black = cv.inRange(hsv, lower_grey, upper_grey)
mask_blue = cv.inRange(hsv, lower_blue, upper_blue)
mask_green =  cv.inRange(hsv, lower_green, upper_green)
mask_red = cv.inRange(hsv, lower_red2, upper_red2)

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [254 254 254]
#   [254 254 254]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [252 252 252]
#   [254 254 254]
#   [254 254 254]]
#
#  [[255 255 255]
#   [255 255 255]
#   [254 254 254]
#   ...
#   [234 234 234]
#   [254 254 254]
#   [254 254 254]]
#
#  ...
#
#  [[255 255 255]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[255 255 255]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
cv_imshow(cv.bitwise_not(mask_black))
cv_imshow(cv.bitwise_not(mask_blue))
cv_imshow(cv.bitwise_not(mask_green))
cv_imshow(cv.bitwise_not(mask_red))
# Out:
# <PIL.Image.Image image mode=L size=378x313 at 0x7F1A44FF5480>
# <PIL.Image.Image image mode=L size=378x313 at 0x7F1A44FF5F60>
# <PIL.Image.Image image mode=L size=378x313 at 0x7F1A44FF5480>
# <PIL.Image.Image image mode=L size=378x313 at 0x7F1A44FF5F60>

# %%
cv_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=378x313 at 0x7F1A44FF5120>
